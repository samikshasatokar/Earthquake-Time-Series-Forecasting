# %% [markdown]
# <a href="https://colab.research.google.com/github/samikshasatokar/Earthquake-Time-Series-Forecasting/blob/main/Execute.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install streamlit -q
# !pip install prophet -q
# Out:
#      |████████████████████████████████| 10.1 MB 12.4 MB/s
#      |████████████████████████████████| 164 kB 53.5 MB/s
#      |████████████████████████████████| 181 kB 51.1 MB/s
#      |████████████████████████████████| 76 kB 5.3 MB/s
#      |████████████████████████████████| 111 kB 35.1 MB/s
#      |████████████████████████████████| 4.3 MB 40.4 MB/s
#      |████████████████████████████████| 63 kB 1.8 MB/s
#      |████████████████████████████████| 130 kB 50.7 MB/s
#      |████████████████████████████████| 130 kB 50.9 MB/s
#      |████████████████████████████████| 793 kB 45.4 MB/s
#      |████████████████████████████████| 428 kB 49.1 MB/s
#      |████████████████████████████████| 381 kB 9.7 MB/s
#   Building wheel for blinker (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jupyter-console 5.2.0 requires prompt-toolkit<2.0.0,>=1.0.0, but you have prompt-toolkit 3.0.29 which is incompatible.
# google-colab 1.0.0 requires ipykernel~=4.10, but you have ipykernel 6.12.1 which is incompatible.
# google-colab 1.0.0 requires ipython~=5.5.0, but you have ipython 7.32.0 which is incompatible.
# google-colab 1.0.0 requires tornado~=5.1.0; python_version >= "3.0", but you have tornado 6.1 which is incompatible.
#      |████████████████████████████████| 65 kB 3.4 MB/s
#      |████████████████████████████████| 49 kB 5.5 MB/s
#      |████████████████████████████████| 43 kB 2.1 MB/s
#   Building wheel for prophet (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# fbprophet 0.7.1 requires cmdstanpy==0.9.5, but you have cmdstanpy 0.9.68 which is incompatible.

# %%
# %%writefile main.py
import streamlit as st
import pandas as pd
import plotly.express as px
from read_me import *
from theory import *
from general_plots_eda import *
from magnitude_regressors import *
from magnitude_prophet import *
from depth_data_cleaning import *
from depth_prophet import *
from depth_regressors import *
from magnitude_rnn_lstm import *
from depth_rnn_lstm import *
from model_comparison import *
from mag_prophet_error import *
from references import *

st.cache(persist=True)   #provides a caching mechanism that allows your app to stay performant even when loading data from the web, manipulating large datasets, or performing expensive computations.
st.set_page_config(layout="wide")


def load_data():
    eq = pd.read_csv("all_month.csv")
    eq["date"] = pd.to_datetime(eq["date"])
    # seperating 'place' column and only consider city by seperating the location by ', '
    newdf = eq['place'].str.split(', ', expand=True)
    eq['location'] = newdf[1]
    eq_df = eq[['date', 'time', 'latitude', 'longitude', 'location', 'mag', 'depth', 'type']]
    return eq, eq_df


eq, eq_df = load_data()

with st.container(): #Inserts an invisible container into your app that can be used to hold multiple elements.
    st.subheader("***🌏 Quake Forecaster - Earthquake Time Series Forecasting 🌏***")



st.markdown(
    '<link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/bootstrap@4.5.3/dist/css/bootstrap.min.css" integrity="sha384-TX8t27EcRE3e/ihU7zmQxVncDAy5uIKz4rEkgIXeMed4M0jlfIDPvg6uqKI2xXr2" crossorigin="anonymous">',
    unsafe_allow_html=True,
)                                 #https://discuss.streamlit.io/t/why-is-using-html-unsafe/4863

query_params = st.experimental_get_query_params() #Return the query parameters that is currently showing in the browser's URL bar. tabs
tabs = ["Home", "Visualize", "Forecast","Compare Algorithms", "Read Me", "References and Sources"]
if "tab" in query_params:
    active_tab = query_params["tab"][0]
else:
    active_tab = "Home"

if active_tab not in tabs:
    st.experimental_set_query_params(tab="Home")
    active_tab = "Home"

li_items = "".join( #navigation items for your site in a horizontal menu
    f"""
    <li class="nav-item">      
        <a class="nav-link{' active' if t == active_tab else ''}" href="/?tab={t}">{t}</a>
    </li>
    """
    for t in tabs
)
tabs_html = f"""
    <ul class="nav nav-tabs">
    {li_items}
    </ul>
"""

st.markdown(tabs_html, unsafe_allow_html=True)
st.markdown("<br>", unsafe_allow_html=True)

if active_tab == "Home":
    st.sidebar.title("**Quake Forecaster**")  # ** to bold the text
    quote()
    st.image("eq1.png")      #https://docs.streamlit.io/library/api-reference/media/st.image
    theory1()
    st.image("eq2_shaanxi.jpg", caption= " The deadliest Shaanxi(China) Earthquake, 1556. " )
    st.image("eq3_lomaprieta.jpg", caption=" The deadliest Loma Prieta(San Francisco) Earthquake, 1989. ")
    theory2()
    home_sidebar()


if active_tab == "Visualize":

    st.sidebar.title('**Earthquake Dashborad**')
    st.sidebar.markdown(''' 

    Select the different options to vary the Visualization.\n
    All the Charts are interactive.\n
    Scroll the mouse over the Charts to feel the interactive features like Tool tip, Zoom, Pan ''')

    st.header("General Analysis")
    view_data()
    gen_analysis()
    type = st.sidebar.radio("Select the type of Chart", ('Number of Events Occured',
                                                             'Percentage of Events per Month',
                                                             'Proportion of Events',
                                                             'Number of Earthquake Events',
                                                             'Magnitude Repartitions',
                                                             'Depth Repartitions',
                                                             'Places with Highest Magnitudes',
                                                             'Places with Highest Depths',
                                                             'Distribution of earthquakes w.r.t. to Magnitude',
                                                             'Distribution of earthquakes w.r.t. to Depth',
                                                             'Distribution of Magnitude over the period',
                                                             'Distribution of Depth over the period'
                                                             ))

    if type == 'Number of Events Occured':
        number_of_events_occured()

    elif type == 'Percentage of Events per Month':
        percentage_of_events_per_month()

    elif type == 'Proportion of Events':
        proportion_of_events()

    elif type == 'Number of Earthquake Events':
        number_of_earthquake_events()

    elif type == 'Magnitude Repartitions':
        magnitude_repartitions()

    elif type == 'Depth Repartitions':
        depth_repartitions()

    elif type == 'Places with Highest Magnitudes':
        places_with_highest_mags()

    elif type == 'Places with Highest Depths':
        places_with_highest_depths()

    elif type == 'Distribution of earthquakes w.r.t. to Magnitude':
        eq_distr_w_r_t_magnitude()

    elif type == 'Distribution of earthquakes w.r.t. to Depth':
        eq_distr_w_r_t_depth()

    elif type == 'Distribution of Magnitude over the period':
        eq_mag_scatter()

    elif type == 'Distribution of Depth over the period':
        eq_depth_scatter()

    st.sidebar.image("earth-unscreen.gif")

if active_tab == "Forecast":
    st.sidebar.title('Earthquake Time Series Forecaster')
    st.sidebar.markdown(''' 

        Select the different parameter and options to vary the Forecasting algorithms.\n 
        Click the "Forecast" button once you have done selecting the Forecasting algorithm.\n
        Hover the mouse over the charts to feel the interactive features like Tool tip, Zoom, and Pan.

     ''')

    st.header("Time Series Forecasting")
    parameter = st.sidebar.selectbox("Select the parameter", ('Magnitude', 'Depth')) #dropdown menu
    training_model = st.sidebar.selectbox("Select the Training Model", ('Facebook Prophet', 'Regression', 'LSTM'))  #dropdown menu
    if parameter == 'Magnitude':
        st.write("Forecast with respect to Earthquake Magnitude")


        if training_model == 'Facebook Prophet':
            predict_prophet = st.sidebar.button("Forecast")
            st.subheader("Facebook Prophet")
            prophet_info()
            if predict_prophet:
                gif_runner = st.image('earth-unscreen.gif')
                mag_prophet()
                gif_runner.empty()

        if training_model == 'Regression':
            predict_reg = st.sidebar.button("Forecast")
            st.subheader("Regression")
            reg_info()
            if predict_reg:
                gif_runner = st.image('earth-unscreen.gif')
                mag_regressions()
                gif_runner.empty()

        if training_model == 'LSTM':
            predict_lstm = st.sidebar.button("Forecast")
            st.subheader("Long Short-Term Memory Network")
            lstm_info()
            if predict_lstm:
                gif_runner = st.image('earth-unscreen.gif')
                mag_lstm()
                gif_runner.empty()



    if parameter == "Depth":
        st.write("Forecasts with respect to Earthquake Depth")


        if training_model == 'Facebook Prophet':
            predict_prophet = st.sidebar.button("Forecast")
            st.subheader("Facebook Prophet")
            prophet_info()
            if predict_prophet:
                gif_runner = st.image('earth-unscreen.gif')
                dep_prophet()
                gif_runner.empty()

        if training_model == 'Regression':
            predict_reg = st.sidebar.button("Forecast")
            st.subheader("Regression")
            reg_info()
            if predict_reg:
                gif_runner = st.image('earth-unscreen.gif')
                dep_regressions()
                gif_runner.empty()

        if training_model == 'LSTM':
            predict_lstm = st.sidebar.button("Forecast")
            st.subheader("Long Short-Term Memory Network")
            lstm_info()
            if predict_lstm:
                gif_runner = st.image('earth-unscreen.gif')
                dep_lstm()
                gif_runner.empty()




if active_tab == "Compare Algorithms":
    compare_info()
    st.sidebar.markdown(''' 

            Select the different parameter and options to vary the parameters.\n 
            Click the "Compare" button once you have done selecting the parameter.\n
            Hover the mouse over the charts to feel the interactive features like Tool tip, Zoom, and Pan.

         ''')
    st.sidebar.title('Algorithm Comparison')
    cmp_parameter = st.sidebar.radio("Select the parameter", ('Magnitude', 'Depth'))
    if cmp_parameter == 'Magnitude':
        cmp_mag = st.sidebar.button("Compare")
        if cmp_mag:
            gif_runner = st.image('earth-unscreen.gif')
            st.write("Listed below are the various algorithms used in this work along with their respective Mean Squared Errors.")
            compare_mag_models()

            gif_runner.empty()


    if cmp_parameter == 'Depth':
        cmp_dep = st.sidebar.button("Compare")
        if cmp_dep:
            gif_runner = st.image('earth-unscreen.gif')
            st.write("Listed below are the various algorithms used in this work along with their respective Mean Squared Errors.")
            compare_dep_models()
            gif_runner.empty()




if active_tab == "Read Me":
    readme_1()



if active_tab == "References and Sources":
    sources()
    ref()
    other_links()
# Out:
# Overwriting main.py

# %%
# !streamlit run main.py & npx localtunnel --port 8501
# Out:
# 2022-04-05 16:13:31.044 INFO    numexpr.utils: NumExpr defaulting to 2 threads.
#
#   You can now view your Streamlit app in your browser.
#
#   Network URL: http://172.28.0.2:8501
#   External URL: http://35.195.194.141:8501
#
# npx: installed 22 in 4.361s
# your url is: https://unlucky-snail-43.loca.lt
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 14150 entries, 2020-07-12 10:31:53.318000+00:00 to 2020-08-11 10:18:15.699000+00:00
# Data columns (total 22 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   latitude         14150 non-null  float64
#  1   longitude        14150 non-null  float64
#  2   depth            14150 non-null  float64
#  3   mag              14149 non-null  float64
#  4   magType          14149 non-null  object
#  5   nst              9960 non-null   float64
#  6   gap              11163 non-null  float64
#  7   dmin             10192 non-null  float64
#  8   rms              14150 non-null  float64
#  9   net              14150 non-null  object
#  10  id               14150 non-null  object
#  11  updated          14150 non-null  object
#  12  place            14150 non-null  object
#  13  type             14150 non-null  object
#  14  horizontalError  8529 non-null   float64
#  15  depthError       14150 non-null  float64
#  16  magError         8972 non-null   float64
#  17  magNst           9306 non-null   float64
#  18  status           14150 non-null  object
#  19  locationSource   14150 non-null  object
#  20  magSource        14150 non-null  object
#  21  date             14150 non-null  object
# dtypes: float64(12), object(10)
# memory usage: 2.5+ MB
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 14150 entries, 2020-07-12 10:31:53.318000+00:00 to 2020-08-11 10:18:15.699000+00:00
# Data columns (total 22 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   latitude         14150 non-null  float64
#  1   longitude        14150 non-null  float64
#  2   depth            14150 non-null  float64
#  3   mag              14149 non-null  float64
#  4   magType          14149 non-null  object
#  5   nst              9960 non-null   float64
#  6   gap              11163 non-null  float64
#  7   dmin             10192 non-null  float64
#  8   rms              14150 non-null  float64
#  9   net              14150 non-null  object
#  10  id               14150 non-null  object
#  11  updated          14150 non-null  object
#  12  place            14150 non-null  object
#  13  type             14150 non-null  object
#  14  horizontalError  8529 non-null   float64
#  15  depthError       14150 non-null  float64
#  16  magError         8972 non-null   float64
#  17  magNst           9306 non-null   float64
#  18  status           14150 non-null  object
#  19  locationSource   14150 non-null  object
#  20  magSource        14150 non-null  object
#  21  date             14150 non-null  object
# dtypes: float64(12), object(10)
# memory usage: 2.5+ MB
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# 2022-04-05 16:16:27.229 Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/streamlit/scriptrunner/script_runner.py", line 443, in _run_script
#     exec(code, module.__dict__)
#   File "/content/main.py", line 14, in <module>
#     from model_comparison import *
#   File "/content/model_comparison.py", line 7, in <module>
#     from dep_reg_error import *
# ModuleNotFoundError: No module named 'dep_reg_error'
#
# 2022-04-05 16:17:37.483 Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/streamlit/scriptrunner/script_runner.py", line 443, in _run_script
#     exec(code, module.__dict__)
#   File "/content/main.py", line 14, in <module>
#     from model_comparison import *
#   File "/content/model_comparison.py", line 7, in <module>
#     from dep_reg_error import *
# ModuleNotFoundError: No module named 'dep_reg_error'
#
# 2022-04-05 16:20:12.695 Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 2022-04-05 16:20:12.696 Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Initial log joint probability = -41.496
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       6548.27   0.000481359        128.82      0.5144      0.5144      112
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      177        6549.1   4.21837e-07       78.6964           1           1      216
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# 2022-04-05 16:32:28.020568: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2022-04-05 16:32:28.049 InMemoryFileManager: Missing file 8f8dc171102a443fabcda063f96ceba889c8c6e3a2337a3bc53598a8.gif
# Epoch 1/50
# 112/112 [==============================] - 7s 11ms/step - loss: 51.1932 - val_loss: 50.4374
# Epoch 2/50
# 112/112 [==============================] - 1s 6ms/step - loss: 47.1422 - val_loss: 45.3950
# Epoch 3/50
# 112/112 [==============================] - 1s 6ms/step - loss: 39.2981 - val_loss: 35.4979
# Epoch 4/50
# 112/112 [==============================] - 1s 6ms/step - loss: 32.2559 - val_loss: 31.5205
# Epoch 5/50
# 112/112 [==============================] - 1s 7ms/step - loss: 29.3965 - val_loss: 29.2542
# Epoch 6/50
# 112/112 [==============================] - 1s 6ms/step - loss: 27.4461 - val_loss: 27.5025
# Epoch 7/50
# 112/112 [==============================] - 1s 6ms/step - loss: 25.8626 - val_loss: 26.0179
# Epoch 8/50
# 112/112 [==============================] - 1s 6ms/step - loss: 24.5111 - val_loss: 24.7284
# Epoch 9/50
# 112/112 [==============================] - 1s 6ms/step - loss: 23.3307 - val_loss: 23.6074
# Epoch 10/50
# 112/112 [==============================] - 1s 7ms/step - loss: 22.2846 - val_loss: 22.5979
# Epoch 11/50
# 112/112 [==============================] - 1s 7ms/step - loss: 21.3526 - val_loss: 21.6972
# Epoch 12/50
# 112/112 [==============================] - 1s 8ms/step - loss: 20.5228 - val_loss: 20.8938
# Epoch 13/50
# 112/112 [==============================] - 2s 18ms/step - loss: 19.7866 - val_loss: 20.1863
# Epoch 14/50
# 112/112 [==============================] - 1s 6ms/step - loss: 19.1332 - val_loss: 19.5468
# Epoch 15/50
# 112/112 [==============================] - 2s 18ms/step - loss: 18.5550 - val_loss: 18.9871
# Epoch 16/50
# 112/112 [==============================] - 1s 7ms/step - loss: 18.0390 - val_loss: 18.4846
# Epoch 17/50
# 112/112 [==============================] - 1s 6ms/step - loss: 17.5849 - val_loss: 18.0372
# Epoch 18/50
# 112/112 [==============================] - 3s 23ms/step - loss: 17.1876 - val_loss: 17.6586
# Epoch 19/50
# 112/112 [==============================] - 1s 7ms/step - loss: 16.8426 - val_loss: 17.3168
# Epoch 20/50
# 112/112 [==============================] - 1s 7ms/step - loss: 16.5401 - val_loss: 17.0246
# Epoch 21/50
# 112/112 [==============================] - 1s 6ms/step - loss: 16.2819 - val_loss: 16.7691
# Epoch 22/50
# 112/112 [==============================] - 1s 6ms/step - loss: 16.0592 - val_loss: 16.5515
# Epoch 23/50
# 112/112 [==============================] - 1s 7ms/step - loss: 15.8685 - val_loss: 16.3703
# Epoch 24/50
# 112/112 [==============================] - 1s 6ms/step - loss: 15.7050 - val_loss: 16.2007
# Epoch 25/50
# 112/112 [==============================] - 1s 7ms/step - loss: 15.5673 - val_loss: 16.0666
# Epoch 26/50
# 112/112 [==============================] - 1s 7ms/step - loss: 15.4512 - val_loss: 15.9529
# Epoch 27/50
# 112/112 [==============================] - 1s 7ms/step - loss: 15.3516 - val_loss: 15.8499
# Epoch 28/50
# 112/112 [==============================] - 1s 7ms/step - loss: 15.2654 - val_loss: 15.7634
# Epoch 29/50
# 112/112 [==============================] - 1s 6ms/step - loss: 15.1912 - val_loss: 15.6898
# Epoch 30/50
# 112/112 [==============================] - 1s 8ms/step - loss: 15.1237 - val_loss: 15.6152
# Epoch 31/50
# 112/112 [==============================] - 1s 6ms/step - loss: 15.0603 - val_loss: 15.5509
# Epoch 32/50
# 112/112 [==============================] - 1s 6ms/step - loss: 14.9980 - val_loss: 15.4844
# Epoch 33/50
# 112/112 [==============================] - 1s 7ms/step - loss: 14.9283 - val_loss: 15.4108
# Epoch 34/50
# 112/112 [==============================] - 1s 7ms/step - loss: 14.8131 - val_loss: 15.3151
# Epoch 35/50
# 112/112 [==============================] - 1s 6ms/step - loss: 14.6542 - val_loss: 15.2064
# Epoch 36/50
# 112/112 [==============================] - 1s 7ms/step - loss: 14.5583 - val_loss: 15.1254
# Epoch 37/50
# 112/112 [==============================] - 1s 7ms/step - loss: 14.4533 - val_loss: 15.0581
# Epoch 38/50
# 112/112 [==============================] - 1s 6ms/step - loss: 14.3694 - val_loss: 14.9765
# Epoch 39/50
# 112/112 [==============================] - 1s 6ms/step - loss: 14.2935 - val_loss: 14.8928
# Epoch 40/50
# 112/112 [==============================] - 1s 7ms/step - loss: 14.2194 - val_loss: 14.8160
# Epoch 41/50
# 112/112 [==============================] - 1s 7ms/step - loss: 14.1501 - val_loss: 14.7546
# Epoch 42/50
# 112/112 [==============================] - 1s 6ms/step - loss: 14.0837 - val_loss: 14.6830
# Epoch 43/50
# 112/112 [==============================] - 1s 7ms/step - loss: 14.0224 - val_loss: 14.6211
# Epoch 44/50
# 112/112 [==============================] - 1s 7ms/step - loss: 13.9642 - val_loss: 14.5616
# Epoch 45/50
# 112/112 [==============================] - 1s 8ms/step - loss: 13.9050 - val_loss: 14.4980
# Epoch 46/50
# 112/112 [==============================] - 1s 6ms/step - loss: 13.8503 - val_loss: 14.4419
# Epoch 47/50
# 112/112 [==============================] - 1s 7ms/step - loss: 13.7998 - val_loss: 14.3949
# Epoch 48/50
# 112/112 [==============================] - 1s 6ms/step - loss: 13.7479 - val_loss: 14.3357
# Epoch 49/50
# 112/112 [==============================] - 1s 6ms/step - loss: 13.7060 - val_loss: 14.2849
# Epoch 50/50
# 112/112 [==============================] - 1s 6ms/step - loss: 13.6591 - val_loss: 14.2514
# /content/depth_rnn_lstm.py:171: MatplotlibDeprecationWarning:
#
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#
# 2022-04-05 16:34:36.184 Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 2022-04-05 16:34:36.184 Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Initial log joint probability = -41.496
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       6548.27   0.000481359        128.82      0.5144      0.5144      112
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      177        6549.1   4.21837e-07       78.6964           1           1      216
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# Epoch 1/50
# 112/112 [==============================] - 3s 12ms/step - loss: 2.5647 - val_loss: 1.9656
# Epoch 2/50
# 112/112 [==============================] - 1s 7ms/step - loss: 1.2998 - val_loss: 0.8085
# Epoch 3/50
# 112/112 [==============================] - 1s 6ms/step - loss: 0.5603 - val_loss: 0.3558
# Epoch 4/50
# 112/112 [==============================] - 1s 6ms/step - loss: 0.2947 - val_loss: 0.2375
# Epoch 5/50
# 112/112 [==============================] - 1s 7ms/step - loss: 0.2481 - val_loss: 0.2267
# Epoch 6/50
# 112/112 [==============================] - 1s 6ms/step - loss: 0.2440 - val_loss: 0.2252
# Epoch 7/50
# 112/112 [==============================] - 1s 6ms/step - loss: 0.2432 - val_loss: 0.2248
# Epoch 8/50
# 112/112 [==============================] - 1s 6ms/step - loss: 0.2426 - val_loss: 0.2243
# Epoch 9/50
# 112/112 [==============================] - 1s 6ms/step - loss: 0.2421 - val_loss: 0.2239
# Epoch 10/50
# 112/112 [==============================] - 1s 6ms/step - loss: 0.2416 - val_loss: 0.2234
# Epoch 11/50
# 112/112 [==============================] - 1s 6ms/step - loss: 0.2410 - val_loss: 0.2229
# Epoch 12/50
# 112/112 [==============================] - 1s 6ms/step - loss: 0.2404 - val_loss: 0.2225
# Epoch 13/50
# 112/112 [==============================] - 1s 6ms/step - loss: 0.2398 - val_loss: 0.2220
# Epoch 14/50
# 112/112 [==============================] - 1s 6ms/step - loss: 0.2393 - val_loss: 0.2216
# Epoch 15/50
# 112/112 [==============================] - 1s 7ms/step - loss: 0.2389 - val_loss: 0.2211
# Epoch 16/50
# 112/112 [==============================] - 1s 6ms/step - loss: 0.2383 - val_loss: 0.2207
# Epoch 17/50
# 112/112 [==============================] - 1s 7ms/step - loss: 0.2377 - val_loss: 0.2203
# Epoch 18/50
# 112/112 [==============================] - 1s 7ms/step - loss: 0.2373 - val_loss: 0.2198
# Epoch 19/50
# 112/112 [==============================] - 1s 6ms/step - loss: 0.2367 - val_loss: 0.2194
# Epoch 20/50
# 112/112 [==============================] - 1s 6ms/step - loss: 0.2362 - val_loss: 0.2189
# Epoch 21/50
# 112/112 [==============================] - 1s 6ms/step - loss: 0.2355 - val_loss: 0.2185
# Epoch 22/50
# 112/112 [==============================] - 1s 6ms/step - loss: 0.2351 - val_loss: 0.2180
# Epoch 23/50
# 112/112 [==============================] - 1s 6ms/step - loss: 0.2346 - val_loss: 0.2176
# Epoch 24/50
# 112/112 [==============================] - 1s 7ms/step - loss: 0.2340 - val_loss: 0.2174
# Epoch 25/50
# 112/112 [==============================] - 1s 6ms/step - loss: 0.2335 - val_loss: 0.2168
# Epoch 26/50
# 112/112 [==============================] - 1s 6ms/step - loss: 0.2330 - val_loss: 0.2163
# Epoch 27/50
# 112/112 [==============================] - 1s 8ms/step - loss: 0.2325 - val_loss: 0.2160
# Epoch 28/50
# 112/112 [==============================] - 1s 7ms/step - loss: 0.2320 - val_loss: 0.2157
# Epoch 29/50
# 112/112 [==============================] - 1s 6ms/step - loss: 0.2315 - val_loss: 0.2152
# Epoch 30/50
# 112/112 [==============================] - 1s 6ms/step - loss: 0.2311 - val_loss: 0.2149
# Epoch 31/50
# 112/112 [==============================] - 1s 6ms/step - loss: 0.2306 - val_loss: 0.2145
# Epoch 32/50
# 112/112 [==============================] - 1s 6ms/step - loss: 0.2302 - val_loss: 0.2142
# Epoch 33/50
# 112/112 [==============================] - 1s 7ms/step - loss: 0.2297 - val_loss: 0.2138
# Epoch 34/50
# 112/112 [==============================] - 1s 6ms/step - loss: 0.2294 - val_loss: 0.2135
# Epoch 35/50
# 112/112 [==============================] - 1s 8ms/step - loss: 0.2291 - val_loss: 0.2132
# Epoch 36/50
# 112/112 [==============================] - 1s 8ms/step - loss: 0.2286 - val_loss: 0.2129
# Epoch 37/50
# 112/112 [==============================] - 1s 7ms/step - loss: 0.2282 - val_loss: 0.2127
# Epoch 38/50
# 112/112 [==============================] - 1s 6ms/step - loss: 0.2280 - val_loss: 0.2124
# Epoch 39/50
# 112/112 [==============================] - 1s 6ms/step - loss: 0.2275 - val_loss: 0.2122
# Epoch 40/50
# 112/112 [==============================] - 1s 6ms/step - loss: 0.2273 - val_loss: 0.2120
# Epoch 41/50
# 112/112 [==============================] - 1s 6ms/step - loss: 0.2269 - val_loss: 0.2119
# Epoch 42/50
# 112/112 [==============================] - 1s 6ms/step - loss: 0.2265 - val_loss: 0.2117
# Epoch 43/50
# 112/112 [==============================] - 1s 7ms/step - loss: 0.2264 - val_loss: 0.2114
# Epoch 44/50
# 112/112 [==============================] - 1s 7ms/step - loss: 0.2261 - val_loss: 0.2113
# Epoch 45/50
# 112/112 [==============================] - 1s 8ms/step - loss: 0.2260 - val_loss: 0.2111
# Epoch 46/50
# 112/112 [==============================] - 1s 6ms/step - loss: 0.2259 - val_loss: 0.2110
# Epoch 47/50
# 112/112 [==============================] - 1s 7ms/step - loss: 0.2255 - val_loss: 0.2110
# Epoch 48/50
# 112/112 [==============================] - 1s 6ms/step - loss: 0.2254 - val_loss: 0.2108
# Epoch 49/50
# 112/112 [==============================] - 1s 6ms/step - loss: 0.2252 - val_loss: 0.2107
# Epoch 50/50
# 112/112 [==============================] - 1s 8ms/step - loss: 0.2251 - val_loss: 0.2106
# [16:35:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# /root/.npm/_npx/227/lib/node_modules/localtunnel/bin/lt.js:81
#     throw err;
#     ^
#
# Error: connection refused: localtunnel.me:44453 (check your firewall settings)
#     at Socket.<anonymous> (/root/.npm/_npx/227/lib/node_modules/localtunnel/lib/TunnelCluster.js:52:11)
#     at Socket.emit (events.js:315:20)
#     at emitErrorNT (internal/streams/destroy.js:106:8)
#     at emitErrorCloseNT (internal/streams/destroy.js:74:3)
#     at processTicksAndRejections (internal/process/task_queues.js:80:21)
